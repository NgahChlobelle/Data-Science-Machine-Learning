# %%
letters=['a','b','c','d','e']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
#APPEND
letters.append('f')
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
#EXTEND
letters.extend(['g','h'])
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#INSERT
letters.insert(0,1)
letters
# Out:
# [1, 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#REMOVE
letters.remove('a')
letters
# Out:
# [1, 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#INSERT
letters.insert(1,'a')
print(letters)
# Out:
# [1, 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#POP
pop_elements=letters.pop(3)
print(pop_elements)
print(letters)
# Out:
# c
# [1, 'a', 'b', 'd', 'e', 'f', 'g', 'h']

# %%
#INDEX
index=letters.index('e')
print(index)
# Out:
# 4

# %%
#COUNT
count=letters.count('b')
count
# Out:
# 1

# %%
#REMOVE
letters.remove(1)
letters
# Out:
# ['a', 'b', 'd', 'e', 'f', 'g', 'h']

# %%
#EXTEND
letters.extend(['a','c','g','a','e'])
letters
# Out:
# ['a', 'b', 'd', 'e', 'f', 'g', 'h', 'a', 'c', 'g', 'a', 'c', 'g', 'a', 'e']

# %%
#SORT
letters.sort()
letters
# Out:
# ['a', 'a', 'a', 'a', 'b', 'c', 'c', 'd', 'e', 'e', 'f', 'g', 'g', 'g', 'h']

# %%
#REVERSE
letters.reverse()
letters
# Out:
# ['h', 'g', 'g', 'g', 'f', 'e', 'e', 'd', 'c', 'c', 'b', 'a', 'a', 'a', 'a']

# %%
#TUPLE
ngah=('a','b','c','d','e')
ngah
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
#COUNT
count=ngah.count('a')
count
# Out:
# 1

# %%
#INDEX
index=ngah.index('c')
index
# Out:
# 2

# %%
print(ngah[4])
# Out:
# e

# %%
#DICTIONARY (an unordered collection key value pairs)
#method 1
my_dict=dict(name='belle',age=95,city='bamenda')
my_dict
# Out:
# {'name': 'belle', 'age': 95, 'city': 'bamenda'}

# %%
#DICTIONARY (an unordered collection key value pairs)
#method 2
my_dict=dict([('name','belle'),('age',95),('city','bamenda')])
my_dict
# Out:
# {'name': 'belle', 'age': 95, 'city': 'bamenda'}

# %%
#DICTIONARY (an unordered collection key value pairs)
#method 3
my_dict={'name':'belle','age':95,'city':'bamenda'}
my_dict
# Out:
# {'name': 'belle', 'age': 95, 'city': 'bamenda'}

# %%
#DICTIONARY with multiple items method 1
my_dict={'names':('belle','clan','best'),'ages':(95,50,76),'city':('bamenda','douala','maryland')}
my_dict
# Out:
# {'names': ('belle', 'clan', 'best'),
#  'ages': (95, 50, 76),
#  'city': ('bamenda', 'douala', 'maryland')}

# %%
#DICTIONARY with multiple items method 2
my_dict_2=dict([('names',['belle','ngah','awah']),('ages',[15,39,61]),('city',['bamenda','bambili','bambui'])])
my_dict_2
# Out:
# {'names': ['belle', 'ngah', 'awah'],
#  'ages': [15, 39, 61],
#  'city': ['bamenda', 'bambili', 'bambui']}

# %%
#GET
age=my_dict.get('ages')
print(age)
# Out:
# (95, 50, 76)

# %%
#GET
names=my_dict.get('names')
print(names)
# Out:
# ('belle', 'clan', 'best')

# %%
#ITEMS
items=my_dict.items()
print(items)
# Out:
# dict_items([('names', ('belle', 'clan', 'best')), ('ages', (95, 50, 76)), ('city', ('bamenda', 'douala', 'maryland'))])

# %%
#KEYS
keys=my_dict.keys()
print(keys)
# Out:
# dict_keys(['names', 'ages', 'city'])

# %%
#VALUES
values=my_dict.values()
print(values)
# Out:
# dict_values([('belle', 'clan', 'best'), (95, 50, 76), ('bamenda', 'douala', 'maryland')])

# %%
#UPDATE
my_dict.update({'gender':['female','female','male']})
print(my_dict)
# Out:
# {'names': ('belle', 'clan', 'best'), 'ages': (95, 50, 76), 'city': ('bamenda', 'douala', 'maryland'), 'gender': ['female', 'female', 'male']}
